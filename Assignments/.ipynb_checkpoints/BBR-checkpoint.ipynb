# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from scipy.constants import h, c, k, Wien
plt.style.use(["science", "notebook", "grid"])

# %%
def Plank_law(wavelength:np.ndarray, T:float) -> np.ndarray:
    """ Plank's law
    Args:
        wavelength (np.ndarray): wavelength in m
        T (float): temperature in K
    Returns:
        np.ndarray: spectral radiance in W/m^2/sr/m"""
    exp_factor = (h * c / (wavelength * k * T)) 
    return (2 * h * c**2 / wavelength**5) * np.exp(-exp_factor) / (1 - np.exp(-exp_factor))

def wienslaw(wavelength:np.ndarray, T:float) -> np.ndarray:
    """ Wiens' law 
    Args:
        wavelength (np.ndarray): wavelength in m
        T (float): temperature in K
    Returns:
        np.ndarray: spectral radiance in W/m^2/sr/m"""
    pre_factor = 2 * h * c**2 / wavelength**5
    exp_factor = np.exp(-h * c / (wavelength * k * T))
    return pre_factor * exp_factor

def RayLeighJeansLaw(wavelength:np.ndarray, T:float) -> np.ndarray:
    """ Rayleigh-Jeans' law
    Args:
        wavelength (np.ndarray): wavelength in m
        T (float): temperature in K
    Returns:
        np.ndarray: spectral radiance in W/m^2/sr/m"""
    return 2 * c * k * T / wavelength**4

def WienDisplacementLaw(T:float) -> np.ndarray:  
    """ Wien's displacement law
    Args:
        wavelength (np.ndarray): wavelength in m
        T (float): temperature in K
    Returns:
        np.ndarray: Wave length in m"""
    return T/Wien


wavelength : np.ndarray = np.logspace(-9, 1, 10000)
T :float = 5000

# %% [markdown]
# #### Plotting

# %% [markdown]
# Plot the Planck’s function Bλ (λ ,T ), in a log-log plot (use the command ‘loglog(lambda,Blambda))’, as a function of wavelength (λ) ranging from 1 nm to 1 m (use 10000 log-spaced data points) at a given temperature, T= 5000 K. Plot the Wien’s law and the Rayleigh-Jeans law superposed on the Planck function to show their discrepancies at large and small wavelengths respectively. Set the range of the y-axis as 10−10 to 1020.

# %%
plt.figure(figsize=(15, 8))
# Set Limits
plt.ylim(10e-10, 10e20)

# Plot Plank's law, rayleigh-jeans' law and wiens' law
plt.loglog(wavelength, Plank_law(wavelength, T), 'k-', label="Plank's law",
           alpha=1);
plt.loglog(wavelength, wienslaw(wavelength, T), 'r:', label="Wiens' law",
           lw = 3);
plt.loglog(wavelength, RayLeighJeansLaw(wavelength, T), 'g-.',
           label="Rayleigh-Jeans' law");

# Set axis labels, titles and decorators in latex
plt.xlabel(r"$\lambda$ [m]", fontsize=20);
plt.ylabel(r"$B_\lambda$ [W/m$^2$/sr/m]", fontsize=20);
plt.title(r"Blackbody radiation at $T = 5000$ K", fontsize=20);
plt.locator_params(axis="both", numticks=20);

# Set legend
plt.legend();

# %% [markdown]
# ## Peak Finding
# Observe from your plot the wavelength at which Bλ peaks? Use the function, max in Python max(B) on the array of Bλ created in the earlier exercise to find the peak of the spectrum. Find the corresponding wavelength, λmax. In- dicate with a point marker the peak value on the plot, using the command loglog(lambda_max,Bmax,’ro’,ms=10). Include the details of the point marker in the legend of the plot. You could choose to adjust the font size by in- cluding plt.legend(fontsize=20) in the code.

# %%
intensity = Plank_law(wavelength, T)
max_wavelength = wavelength[np.argmax(intensity)]

# %% [markdown]
# #### Comment: Another neat method to find the peak in a signal
# (I learnt this in my dissertation work 😅)

# %%
# First we calculate the dydx(slope) of the signal
dydx = np.gradient(intensity, wavelength)

# Then we multiply adjacent elements of the slopes to find the sign changes
sign_changes = dydx[1:] * dydx[:-1]

# Wherever the slope changes is less than zero, we have a local extremum
# Then we index the wavelength array with this index to find the wavelength 
# of the local extremum
max_wavelength_other_method = wavelength[1:][sign_changes < 0][0]

# Check if the two methods give the same result
print("Wavelength of maximum intensity with first method: ", max_wavelength)
print("Wavelength of maximum intensity with second method: ", max_wavelength_other_method)

print(f"Do the 2 methods give the same result? {max_wavelength == max_wavelength_other_method}")
# Out:
# Wavelength of maximum intensity with first method:  5.797974856117092e-07
# Wavelength of maximum intensity with second method:  5.797974856117092e-07
# Do the 2 methods give the same result? True

# %% [markdown]
# **Adding the point to the code**

# %%
plt.figure(figsize=(15, 8))
# Set Limits
plt.ylim(10e-10, 10e20)

# Plot Plank's law, rayleigh-jeans' law and wiens' law
plt.loglog(wavelength, Plank_law(wavelength, T), 'k-', label="Plank's law",
           alpha=1);


# Set axis labels, titles and decorators in latex
plt.xlabel(r"$\lambda$ [m]", fontsize=20);
plt.ylabel(r"$B_\lambda$ [W/m$^2$/sr/m]", fontsize=20);
plt.title(r"Blackbody radiation at $T = 5000$ K", fontsize=20);
plt.locator_params(axis="both", numticks=20);

# Adding the maximum wavelength with a text box describing it
plt.text(max_wavelength, 6*10e13, 
         rf"$\lambda$ = {max_wavelength:.3e}, $B_\lambda$ = {Plank_law(max_wavelength, T):.3e}", 
         fontsize=16,
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.scatter(max_wavelength, Plank_law(max_wavelength, T), marker='o', color='r', s=80,
            label="Maximum intensity", edgecolor = "k");


# Join the point with the axis
plt.axvline(max_wavelength, color='r', linestyle='--', alpha=0.5);
plt.axhline(Plank_law(max_wavelength, T), color='r', linestyle='--', alpha=0.5);

# Set legend
plt.legend();

# %% [markdown]
# ---
# ## Color finding
# What colour does the peak wavelength correspond to? Does it match with your calculation from the well-known Wien’s displacement law?

# %%
# Get color from wavelength
def wavelength_to_rgb(wavelength:float, gamma:float=0.8) -> tuple:
    """ Convert wavelength to RGB color
    Args:
        wavelength (float): wavelength in nm
        gamma (float, optional): gamma value. Defaults to 0.8.
    Returns:
        tuple: RGB color
    """
    wavelength = float(wavelength) * 1e9
    if wavelength >= 380 and wavelength <= 440:
        attenuation = 0.3 + 0.7 * (wavelength - 380) / (440 - 380)
        R = ((-(wavelength - 440) / (440 - 380)) * attenuation) ** gamma
        G = 0.0
        B = (1.0 * attenuation) ** gamma
    elif wavelength >= 440 and wavelength <= 490:
        R = 0.0
        G = ((wavelength - 440) / (490 - 440)) ** gamma
        B = 1.0
    elif wavelength >= 490 and wavelength <= 510:
        R = 0.0
        G = 1.0
        B = (-(wavelength - 510) / (510 - 490)) ** gamma
    elif wavelength >= 510 and wavelength <= 580:
        R = ((wavelength - 510) / (580 - 510)) ** gamma
        G = 1.0
        B = 0.0
    elif wavelength >= 580 and wavelength <= 645:
        R = 1.0
        G = (-(wavelength - 645) / (645 - 580)) ** gamma
        B = 0.0
    elif wavelength >= 645 and wavelength <= 750:
        attenuation = 0.3 + 0.7 * (750 - wavelength) / (750 - 645)
        R = (1.0 * attenuation) ** gamma
        G = 0.0
        B = 0.0
    else:
        R = 0.0
        G = 0.0
        B = 0.0
    R *= 255
    G *= 255
    B *= 255
    return (int(R)/256, int(G)/256, int(B)/256)

# %%
plt.figure(figsize=(15, 8))
# Set Limits
plt.ylim(10e-10, 10e20)

# Plot Plank's law, rayleigh-qjeans' law and wiens' law
plt.loglog(wavelength, Plank_law(wavelength, T), 'k-', label="Plank's law",
           alpha=1);


# Set axis labels, titles and decorators in latex
plt.xlabel(r"$\lambda$ [m]", fontsize=20);
plt.ylabel(r"$B_\lambda$ [W/m$^2$/sr/m]", fontsize=20);
plt.title(r"Blackbody radiation at $T = 5000$ K", fontsize=20);
plt.locator_params(axis="both", numticks=20);

# Adding the maximum wavelength with a text box describing it
plt.text(max_wavelength+1e-6, 6*10e13, 
         rf"$\lambda$ = {max_wavelength:.3e}, $B_\lambda$ = {Plank_law(max_wavelength, T):.3e}", 
         fontsize=16,
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))

plt.scatter(max_wavelength, Plank_law(max_wavelength, T), marker='o', color='r', s=80,
            label="Maximum intensity", edgecolor = "k");

# Get Color of maximum wavelength
color = wavelength_to_rgb(max_wavelength)  # (0.9921875, 0.99609375, 0.0)

# Plot the spectrum
plt.fill_between([max_wavelength-1e-7, max_wavelength+1e-7], [10e21, 10e21], color=color, alpha=0.5,
                    label="Spectrum")


# Join the point with the axis
plt.axvline(max_wavelength, color='r', linestyle='--', alpha=0.5);
plt.axhline(Plank_law(max_wavelength, T), color='r', linestyle='--', alpha=0.5);

# Set legend
plt.legend();

# %% [markdown]
# Plot Bλ as a function of wavelength λ (0.001 nm ≤ λ ≤ 10 m) in a log-log plot (generate 10000 logarithmically spaced data points for each of the curves), for various temperatures ranging from 1 K ≤ T ≤ 108 K, incrementing in factors of 10. Set the lower limit of the y-axis to 1010. A snippet of the code to be used for plotting is given below:
#
# ```python
# loglog(lmb,Blmb)
# ylim(bottom=(1,e−10))
# xlim ( [ ( 1 . e −12) ,10.])
# ```

# %%
wavelength = np.logspace(-12, 1, 10000)
Temp = np.logspace(0, 9, 10)

plt.figure(figsize=(15, 8))

# Set Limits
plt.ylim(10e-10, 10e40)

for temp in Temp:
    plt.loglog(wavelength, Plank_law(wavelength, temp), label=f"T = {temp:.2e}")

# Set decorations
plt.xlabel(r"$\lambda$ [m]", fontsize=20);
plt.ylabel(r"$B_\lambda$ [W/m$^2$/sr/m]", fontsize=20);
plt.title("Blackbody radiation at different temperatures (in K)", fontsize=20);
plt.locator_params(axis="both", numticks=20);

# Set legend
plt.legend();

# %% [markdown]
# Using the Wien’s displacement law, generate an array of the wavelengths, λmax, at which the spectral radiance peaks for each of the Planck curves at different temperatures (1 K ≤ T ≤ 108 K), plotted in the earlier question. Use the Planck function to generate an array of the corresponding spectral radiances, Bλ (λmax ,T), for each of these wavelengths at the different temperatures. Plot this data-set of Bλ (λmax ,T) with λmax, superposed on the earlier generated plot of the Planck curves. Observe and comment on the nature of this curve

# %%
peak_wavelengths = WienDisplacementLaw(Temp)
Temp_vals = np.linspace(3000, 10000, 10)


# Plot the intensitites vs wavelength for diff temperatures on subplots
fig, axs = plt.subplots(5, 2, figsize=(20, 16), sharex=True, sharey=True)
ax = axs.ravel()
fig.suptitle("Blackbody radiation at different temperatures (in K)", fontsize=20, 
             y=1.05, fontweight = "bold")
plt.ylim(10e-10, 10e20)
plt.xlim(10e-9, 1)

for idx, wave in enumerate(peak_wavelengths):
    for temp in Temp_vals:
        ax[idx].loglog(wavelength, Plank_law(wavelength, temp))
    ax[idx].set_title(f"$\lambda$ = {wave:.8e}")
    ax[idx].set_xlabel(r"$\lambda$ [m]", fontsize=20)
    ax[idx].set_ylabel(r"$B_\lambda$ [W/m$^2$/sr/m]", fontsize=20)
plt.tight_layout()

# Put one single legend for all th graphs with 5 columns
fig.legend(Temp_vals, loc=1, ncol=1, fontsize=12, title="Temperature (in K)", 
           bbox_to_anchor=(1.12, 1.1), bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# Generate a log-log plot for the Rayleigh-Jeans law, superposed on the Planck spectrum for low temperature (1 K) and high temperature (104 K) for the wavelength range 10 nm to 10 m. Set the range of the y-axis between 10−19 to 1020. Compare the two Rayleigh-Jeans curves with the Planck curves and observe the severity of the ultraviolet catastrophe for low temperature.

# %%
wavelengths = np.logspace(-9, 1, 10)
wavelengths
# Out:
# array([1.00000000e-09, 1.29154967e-08, 1.66810054e-07, 2.15443469e-06,
#        2.78255940e-05, 3.59381366e-04, 4.64158883e-03, 5.99484250e-02,
#        7.74263683e-01, 1.00000000e+01])

# %%
wavelengths = np.logspace(-9, 1, 10000)
temperatures = np.array([1000, 10e4])

# Get intensities
# intensity_Plank = np.array([Plank_law(wavelengths, temperatures[0]), 
#                             Plank_law(wavelengths, temperatures[1])])

# intensity_Rayleigh = np.array([RayLeighJeansLaw(wavelengths, temperatures[0]),
#                                  RayLeighJeansLaw(wavelengths, temperatures[1])])

fig, ax = plt.subplots(2, 1, figsize = (15, 12))
ax = ax.ravel()

for idx, temp in enumerate(temperatures):
        ax[idx].loglog(wavelengths, Plank_law(wavelengths, temp), 'k',
                       label=f"Plank's law ")
        ax[idx].loglog(wavelengths, RayLeighJeansLaw(wavelengths, temp), 'r--',
                       label=f"Rayleigh-Jeans' law ")
        ax[idx].set_title(f"Blackbody radiation at temperature {temp:,}K",
                          fontsize=20, fontweight="bold")
        ax[idx].set_ylim(10e-10, 10e20)
        ax[idx].set_xlabel(r"$\lambda$ [m]", fontsize=20)
        ax[idx].set_ylabel(r"$B_\lambda$ [W/m$^2$/sr/m]", fontsize=20)
        ax[idx].locator_params(axis="both", numticks=20)
        ax[idx].legend()

plt.tight_layout()

# %% [markdown]
#  Integrate the Planck function Bλ (λ, T ) over all wavelengths numerically for T = 100 K, 104 K and 108 K, using integration tools available in Scipy. Does your result match with the theoretical result? Use proper scalings and transformation of variables for the integration.

# %%
from scipy.integrate import quad, cumulative_trapezoid, simps

# %%
x_signal = np.linspace(0, np.pi, 1000)
y_signal = np.sin(x_signal)

integral = simps(y_signal, x_signal)
integral2 = cumulative_trapezoid(y_signal, x_signal)[-1]

error1 = np.abs(integral - 2) / 2 * 100
error2 = np.abs(integral2 - 2) / 2 * 100

print(f"Error in simps: {error1}%")
print(f"Error in cumulative_trapezoid: {error2}%")
# Out:
# Error in simps: 1.4941381465405357e-10%
# Error in cumulative_trapezoid: 8.241145735832234e-05%

# %% [markdown]
# $$
# \begin{equation}
# \label{eq1}
# \begin{split}
# A & = \frac{\pi r^2}{2} \\
#  & = \frac{1}{2} \pi r^2
# \end{split}
# \end{equation}
# $$
